# %%
import pandas as pd
df = pd.read_csv('dataset.csv')
df
# Out:
#      temp  humidity  wind  rain  fire_occurred
# 0      32        51     2   4.3              0
# 1      24        21     6   1.2              0
# 2      38        42     3   4.5              0
# 3      33        84     4   3.2              0
# 4      25        79    14   5.0              0
# ..    ...       ...   ...   ...            ...
# 495    22        47     9   2.6              0
# 496    32        60    11   4.8              0
# 497    30        21     4   1.8              0
# 498    36        70     4   3.5              0
# 499    31        74     9   4.5              0
#
# [500 rows x 5 columns]

# %%
df[df.fire_occurred == 1]
# Out:
#      temp  humidity  wind  rain  fire_occurred
# 9      29        50    13   0.2              1
# 16     27        57     8   1.6              1
# 25     40        31    16   0.0              1
# 33     31        53    10   0.2              1
# 35     29        58    16   1.2              1
# 51     34        41     6   1.7              1
# 55     39        35     8   0.9              1
# 63     33        61    20   0.7              1
# 83     36        48    13   1.3              1
# 92     32        64    12   1.5              1
# 127    34        45    16   0.3              1
# 150    40        52    19   0.1              1
# 158    27        34    10   1.4              1
# 175    39        50    20   0.2              1
# 176    36        58    11   1.6              1
# 184    30        37    10   1.5              1
# 209    31        37    12   1.2              1
# 243    30        41    16   0.7              1
# 258    32        24     8   1.0              1
# 271    29        44    19   1.4              1
# 276    35        24    11   1.8              1
# 280    29        49    15   1.0              1
# 298    33        52    18   1.2              1
# 306    39        51     7   1.5              1
# 314    33        63    15   1.8              1
# 325    39        46    15   0.3              1
# 355    40        45    13   0.6              1
# 357    37        61     7   1.5              1
# 380    40        40    19   0.9              1
# 388    36        44    19   0.7              1
# 392    39        26    17   1.3              1
# 404    27        45    16   0.4              1
# 408    31        45    11   1.2              1
# 410    32        61    18   1.3              1
# 418    30        58    18   1.8              1
# 430    35        58    17   0.5              1
# 431    32        64    10   1.3              1
# 432    29        63    14   0.9              1
# 435    27        44    11   1.0              1
# 439    27        60    13   1.0              1
# 442    29        64    16   1.5              1
# 451    30        54     9   1.3              1
# 462    31        56    17   0.4              1
# 489    31        24    16   0.4              1

# %%
df.fire_occurred.unique()
# Out:
# array([0, 1])

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100)
rf.fit(df.drop('fire_occurred', axis=1), df.fire_occurred)
# Out:
# RandomForestClassifier()

# %%
rf.predict([[32,51,2,4.3]])
# Out:
# /home/technomad/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import pickle
with open('rf3.pkl', 'wb') as f:
    pickle.dump(rf, f)
